# %%
import os
import pandas
import fancyimpute as fi
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from scipy.io import savemat
from copy import deepcopy
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Handle non-numeric columns spreadsheet

# %%
def encode(col, code_dict=None, encode_nan = False):
    '''col is a pandas Series or list as input. Code_dict is a dict such that keys are entries
    that exist in col, and values are new entries to replace the key, thus "encoding" the column.
    If code_dict = None, will automatically encode unique values with sequential integers.
    Returns pandas Series.
    If encode_nan, NaNs will be coded as 0s. Otherwise, they will be left as NaNs'''
    
    col = pandas.Series(deepcopy(col))
    net = []
    if not code_dict:
        code_dict = {}
        for i,val in enumerate(col.unique()):
            if pandas.notnull(val):
                code_dict.update({val: i+1})
            else:
                if encode_nan:
                    code_dict.update({val: 0})
    else:
        if type(code_dict) != dict:
            raise ValueError('code_dict must be a dictionary object')
        
    for i,val in enumerate(col):
        if val in code_dict.keys():
            col[i] = code_dict[val]
        else:
            net.append(val)
    if len(net) > 0:
        print('the following values were not assigned labels:')
        for miss in set(net):
            print(miss)
    
    return col, code_dict

# %%
# Note the na_values -- this is because the NaNs were set as a space and it was fuckin shit up
df = pandas.read_csv('/Users/jakevogel/Science/TADPOLE/TADPOLE_D1_D2.csv', na_values=' ')
# Out:
# //anaconda/envs/py3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1413,1656,1657,1659,1665,1666,1895,1902,1903,1904,1905) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df['ventr_ICV_ratio'] = df.Ventricles / df.ICV

# %%
# Try to coerce object dtypes to numeric dtype. If this fails, encode to numerical values manually, save maps
maps = {}
for i,col in enumerate(df.columns[10:]):
    if df[col].dtype == 'object':
        try:
            df[col] = pandas.to_numeric(df[col])
        except:
            print('encoding %s, %s of %s'%(col,i,len(df.columns)))
            newcol, dmap = encode(df[col])
            df[col] = newcol
            maps.update({col: dmap})
# Out:
# encoding PTGENDER, 2 of 1907
# encoding PTETHCAT, 4 of 1907
# encoding PTRACCAT, 5 of 1907
# encoding PTMARRY, 6 of 1907
# encoding FLDSTRENG, 35 of 1907
# the following values were not assigned labels:
# nan
# encoding FSVERSION, 36 of 1907
# the following values were not assigned labels:
# nan
# encoding DX, 44 of 1907
# the following values were not assigned labels:
# nan
# encoding EXAMDATE_bl, 45 of 1907
# encoding FLDSTRENG_bl, 55 of 1907
# the following values were not assigned labels:
# nan
# encoding FSVERSION_bl, 56 of 1907
# the following values were not assigned labels:
# nan
# encoding update_stamp, 86 of 1907
# encoding EXAMDATE_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 87 of 1907
# the following values were not assigned labels:
# nan
# encoding VERSION_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 88 of 1907
# the following values were not assigned labels:
# nan
# encoding RUNDATE_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 93 of 1907
# the following values were not assigned labels:
# nan
# encoding STATUS_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 94 of 1907
# the following values were not assigned labels:
# nan
# encoding OVERALLQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 103 of 1907
# the following values were not assigned labels:
# nan
# encoding TEMPQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 104 of 1907
# the following values were not assigned labels:
# nan
# encoding FRONTQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 105 of 1907
# the following values were not assigned labels:
# nan
# encoding PARQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 106 of 1907
# the following values were not assigned labels:
# nan
# encoding INSULAQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 107 of 1907
# the following values were not assigned labels:
# nan
# encoding OCCQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 108 of 1907
# the following values were not assigned labels:
# nan
# encoding BGQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 109 of 1907
# the following values were not assigned labels:
# nan
# encoding CWMQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 110 of 1907
# the following values were not assigned labels:
# nan
# encoding VENTQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 111 of 1907
# the following values were not assigned labels:
# nan
# encoding update_stamp_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 458 of 1907
# the following values were not assigned labels:
# nan
# encoding EXAMDATE_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 459 of 1907
# the following values were not assigned labels:
# nan
# encoding VERSION_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 460 of 1907
# the following values were not assigned labels:
# nan
# encoding RUNDATE_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 465 of 1907
# the following values were not assigned labels:
# nan
# encoding STATUS_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 466 of 1907
# the following values were not assigned labels:
# nan
# encoding OVERALLQC_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 467 of 1907
# the following values were not assigned labels:
# nan
# encoding TEMPQC_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 468 of 1907
# the following values were not assigned labels:
# nan
# encoding FRONTQC_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 469 of 1907
# the following values were not assigned labels:
# nan
# encoding PARQC_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 470 of 1907
# the following values were not assigned labels:
# nan
# encoding INSULAQC_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 471 of 1907
# the following values were not assigned labels:
# nan
# encoding OCCQC_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 472 of 1907
# the following values were not assigned labels:
# nan
# encoding BGQC_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 473 of 1907
# the following values were not assigned labels:
# nan
# encoding CWMQC_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 474 of 1907
# the following values were not assigned labels:
# nan
# encoding VENTQC_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 475 of 1907
# the following values were not assigned labels:
# nan
# encoding update_stamp_UCSFFSX_11_02_15_UCSFFSX51_08_01_16, 822 of 1907
# the following values were not assigned labels:
# nan
# encoding EXAMDATE_BAIPETNMRC_09_12_16, 823 of 1907
# the following values were not assigned labels:
# nan
# encoding RUNDATE_BAIPETNMRC_09_12_16, 826 of 1907
# the following values were not assigned labels:
# nan
# encoding STATUS_BAIPETNMRC_09_12_16, 827 of 1907
# the following values were not assigned labels:
# nan
# encoding update_stamp_BAIPETNMRC_09_12_16, 1162 of 1907
# the following values were not assigned labels:
# nan
# encoding EXAMDATE_UCBERKELEYAV45_10_17_16, 1163 of 1907
# the following values were not assigned labels:
# nan
# encoding update_stamp_UCBERKELEYAV45_10_17_16, 1402 of 1907
# the following values were not assigned labels:
# nan
# encoding EXAMDATE_UCBERKELEYAV1451_10_17_16, 1403 of 1907
# the following values were not assigned labels:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# encoding COMMENT_UPENNBIOMK9_04_19_17, 1895 of 1907
# the following values were not assigned labels:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# encoding update_stamp_UPENNBIOMK9_04_19_17, 1896 of 1907
# the following values were not assigned labels:
# nan

# %%
# Yasser wanted me to save this to a matfile. It took like 30 minutes and was like 1.5GB :-{
ddict = {}
ddict.update({'data': df.values})
ddict.update({'columns': df.columns.tolist()})
newmat = savemat('/Users/jakevogel/Science/TADPOLE/encoded',ddict)

# %%
# Save encoded data to CSV ... takes a few seconds ;-)
df.to_csv('/Users/jakevogel/Science/TADPOLE/encoded.csv')

# %%
# save maps to a file
fields = []
frames = []
for field, d in maps.items():
    fields.append(field)
    frames.append(pandas.DataFrame.from_dict(d, orient='index'))

map_df = pandas.concat(frames, keys=fields)
map_df.to_csv('/Users/jakevogel/Science/TADPOLE/data_map')

# %% [markdown]
# ## Interpolation

# %%
df = pandas.read_csv('/Users/jakevogel/Science/TADPOLE/encoded.csv')

# %%
for i in range(2):
    df.drop(df.columns[0],axis=1,inplace=True)

# %%
# identify percentage of missing values for each column
missing = []
n = df.shape[0]
for col in df.columns[10:]:
    missing.append((len([x for x in df[col] if not pandas.notnull(x)])+0.0000001)/n)

# %%
# plot the distribution. Values of 1 are missing 100% of data, while values of 0 are missing no data.
plt.close()
sns.distplot(missing)
plt.show()

# %%
sorted(missing)[int(len(missing)*.9)]
# Out:
# 0.9930146770347698

# %%
# get indices of columns to keep, and columns to get rid of
bad_idx = [x+10 for x in range(len(missing)) if missing[x] > 0.9]
good_idx = [x+10 for x in range(len(missing)) if missing[x] < 0.9]

# %%
# how many left over?
len([x for x in range(len(missing)) if missing[x] < 0.9])
# Out:
# 1375

# %%
# what percent of columns are we getting rid of?
len([x for x in range(len(missing)) if missing[x] > 0.9]) / (df.shape[-1] - 10)
# Out:
# 0.2755532139093783

# %%
# what are they?
df.columns[bad_idx].tolist()
# Out:
# ['PIB',
#  'PIB_bl',
#  'ST100SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST122SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST126SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST22CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST22SA_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST22TA_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST22TS_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST28CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST33SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST41SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST63SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST67SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST81CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST81SA_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST81TA_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST81TS_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST87CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST92SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#  'ST100SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST122SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST126SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST22CV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST22SA_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST22TA_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST22TS_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST28CV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST33SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST41SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST63SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST67SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST81CV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST81SA_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST81TA_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST81TS_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST87CV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ST92SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#  'ACI_BAIPETNMRC_09_12_16',
#  'PLSFDG01_BAIPETNMRC_09_12_16',
#  'HCI001_BAIPETNMRC_09_12_16',
#  'MCSUVRWM_BAIPETNMRC_09_12_16',
#  'MCSUVRWM2_BAIPETNMRC_09_12_16',
#  'VENTRICLE_5TH_UCBERKELEYAV45_10_17_16',
#  'VENTRICLE_5TH_SIZE_UCBERKELEYAV45_10_17_16',
#  'EXAMDATE_UCBERKELEYAV1451_10_17_16',
#  'CEREBELLUMGREYMATTER_UCBERKELEYAV1451_10_17_16',
#  'CEREBELLUMGREYMATTER_SIZE_UCBERKELEYAV1451_10_17_16',
#  'BRAAK1_UCBERKELEYAV1451_10_17_16',
#  'BRAAK1_SIZE_UCBERKELEYAV1451_10_17_16',
#  'BRAAK2_UCBERKELEYAV1451_10_17_16',
#  'BRAAK2_SIZE_UCBERKELEYAV1451_10_17_16',
#  'BRAAK3_UCBERKELEYAV1451_10_17_16',
#  'BRAAK3_SIZE_UCBERKELEYAV1451_10_17_16',
#  'BRAAK4_UCBERKELEYAV1451_10_17_16',
#  'BRAAK4_SIZE_UCBERKELEYAV1451_10_17_16',
#  'BRAAK5_UCBERKELEYAV1451_10_17_16',
#  'BRAAK5_SIZE_UCBERKELEYAV1451_10_17_16',
#  'BRAAK6_UCBERKELEYAV1451_10_17_16',
#  'BRAAK6_SIZE_UCBERKELEYAV1451_10_17_16',
#  'ERODED_SUBCORTICALWM_UCBERKELEYAV1451_10_17_16',
#  'ERODED_SUBCORTICALWM_SIZE_UCBERKELEYAV1451_10_17_16',
#  'VENTRICLE_3RD_UCBERKELEYAV1451_10_17_16',
#  'VENTRICLE_3RD_SIZE_UCBERKELEYAV1451_10_17_16',
#  'VENTRICLE_4TH_UCBERKELEYAV1451_10_17_16',
#  'VENTRICLE_4TH_SIZE_UCBERKELEYAV1451_10_17_16',
#  'VENTRICLE_5TH_UCBERKELEYAV1451_10_17_16',
#  'VENTRICLE_5TH_SIZE_UCBERKELEYAV1451_10_17_16',
#  'BRAINSTEM_UCBERKELEYAV1451_10_17_16',
#  'BRAINSTEM_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CC_ANTERIOR_UCBERKELEYAV1451_10_17_16',
#  'CC_ANTERIOR_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CC_CENTRAL_UCBERKELEYAV1451_10_17_16',
#  'CC_CENTRAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CC_MID_ANTERIOR_UCBERKELEYAV1451_10_17_16',
#  'CC_MID_ANTERIOR_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CC_MID_POSTERIOR_UCBERKELEYAV1451_10_17_16',
#  'CC_MID_POSTERIOR_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CC_POSTERIOR_UCBERKELEYAV1451_10_17_16',
#  'CC_POSTERIOR_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CSF_UCBERKELEYAV1451_10_17_16',
#  'CSF_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_BANKSSTS_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_BANKSSTS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_CAUDALANTERIORCINGULATE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_CAUDALANTERIORCINGULATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_CAUDALMIDDLEFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_CAUDALMIDDLEFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_CUNEUS_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_CUNEUS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_ENTORHINAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_ENTORHINAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_FRONTALPOLE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_FRONTALPOLE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_FUSIFORM_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_FUSIFORM_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_INFERIORPARIETAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_INFERIORPARIETAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_INFERIORTEMPORAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_INFERIORTEMPORAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_INSULA_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_INSULA_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_ISTHMUSCINGULATE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_ISTHMUSCINGULATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_LATERALOCCIPITAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_LATERALOCCIPITAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_LATERALORBITOFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_LATERALORBITOFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_LINGUAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_LINGUAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_MEDIALORBITOFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_MEDIALORBITOFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_MIDDLETEMPORAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_MIDDLETEMPORAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARACENTRAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARACENTRAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARAHIPPOCAMPAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARAHIPPOCAMPAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARSOPERCULARIS_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARSOPERCULARIS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARSORBITALIS_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARSORBITALIS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARSTRIANGULARIS_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PARSTRIANGULARIS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PERICALCARINE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PERICALCARINE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_POSTCENTRAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_POSTCENTRAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_POSTERIORCINGULATE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_POSTERIORCINGULATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PRECENTRAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PRECENTRAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PRECUNEUS_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_PRECUNEUS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_ROSTRALANTERIORCINGULATE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_ROSTRALANTERIORCINGULATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_ROSTRALMIDDLEFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_ROSTRALMIDDLEFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_SUPERIORFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_SUPERIORFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_SUPERIORPARIETAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_SUPERIORPARIETAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_SUPERIORTEMPORAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_SUPERIORTEMPORAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_SUPRAMARGINAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_SUPRAMARGINAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_TEMPORALPOLE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_TEMPORALPOLE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_TRANSVERSETEMPORAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_TRANSVERSETEMPORAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_UNKNOWN_UCBERKELEYAV1451_10_17_16',
#  'CTX_LH_UNKNOWN_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_BANKSSTS_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_BANKSSTS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_CAUDALANTERIORCINGULATE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_CAUDALANTERIORCINGULATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_CAUDALMIDDLEFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_CAUDALMIDDLEFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_CUNEUS_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_CUNEUS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_ENTORHINAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_ENTORHINAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_FRONTALPOLE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_FRONTALPOLE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_FUSIFORM_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_FUSIFORM_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_INFERIORPARIETAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_INFERIORPARIETAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_INFERIORTEMPORAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_INFERIORTEMPORAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_INSULA_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_INSULA_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_ISTHMUSCINGULATE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_ISTHMUSCINGULATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_LATERALOCCIPITAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_LATERALOCCIPITAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_LATERALORBITOFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_LATERALORBITOFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_LINGUAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_LINGUAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_MEDIALORBITOFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_MEDIALORBITOFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_MIDDLETEMPORAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_MIDDLETEMPORAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARACENTRAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARACENTRAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARAHIPPOCAMPAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARAHIPPOCAMPAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARSOPERCULARIS_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARSOPERCULARIS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARSORBITALIS_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARSORBITALIS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARSTRIANGULARIS_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PARSTRIANGULARIS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PERICALCARINE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PERICALCARINE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_POSTCENTRAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_POSTCENTRAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_POSTERIORCINGULATE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_POSTERIORCINGULATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PRECENTRAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PRECENTRAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PRECUNEUS_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_PRECUNEUS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_ROSTRALANTERIORCINGULATE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_ROSTRALANTERIORCINGULATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_ROSTRALMIDDLEFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_ROSTRALMIDDLEFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_SUPERIORFRONTAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_SUPERIORFRONTAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_SUPERIORPARIETAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_SUPERIORPARIETAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_SUPERIORTEMPORAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_SUPERIORTEMPORAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_SUPRAMARGINAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_SUPRAMARGINAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_TEMPORALPOLE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_TEMPORALPOLE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_TRANSVERSETEMPORAL_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_TRANSVERSETEMPORAL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_UNKNOWN_UCBERKELEYAV1451_10_17_16',
#  'CTX_RH_UNKNOWN_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_ACCUMBENS_AREA_UCBERKELEYAV1451_10_17_16',
#  'LEFT_ACCUMBENS_AREA_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_AMYGDALA_UCBERKELEYAV1451_10_17_16',
#  'LEFT_AMYGDALA_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CAUDATE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CAUDATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CEREBELLUM_CORTEX_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CEREBELLUM_CORTEX_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CEREBELLUM_WHITE_MATTER_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CEREBELLUM_WHITE_MATTER_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CEREBRAL_WHITE_MATTER_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CEREBRAL_WHITE_MATTER_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CHOROID_PLEXUS_UCBERKELEYAV1451_10_17_16',
#  'LEFT_CHOROID_PLEXUS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_HIPPOCAMPUS_UCBERKELEYAV1451_10_17_16',
#  'LEFT_HIPPOCAMPUS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_INF_LAT_VENT_UCBERKELEYAV1451_10_17_16',
#  'LEFT_INF_LAT_VENT_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_LATERAL_VENTRICLE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_LATERAL_VENTRICLE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_PALLIDUM_UCBERKELEYAV1451_10_17_16',
#  'LEFT_PALLIDUM_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_PUTAMEN_UCBERKELEYAV1451_10_17_16',
#  'LEFT_PUTAMEN_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_THALAMUS_PROPER_UCBERKELEYAV1451_10_17_16',
#  'LEFT_THALAMUS_PROPER_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_VENTRALDC_UCBERKELEYAV1451_10_17_16',
#  'LEFT_VENTRALDC_SIZE_UCBERKELEYAV1451_10_17_16',
#  'LEFT_VESSEL_UCBERKELEYAV1451_10_17_16',
#  'LEFT_VESSEL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'NON_WM_HYPOINTENSITIES_UCBERKELEYAV1451_10_17_16',
#  'NON_WM_HYPOINTENSITIES_SIZE_UCBERKELEYAV1451_10_17_16',
#  'OPTIC_CHIASM_UCBERKELEYAV1451_10_17_16',
#  'OPTIC_CHIASM_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_ACCUMBENS_AREA_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_ACCUMBENS_AREA_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_AMYGDALA_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_AMYGDALA_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CAUDATE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CAUDATE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CEREBELLUM_CORTEX_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CEREBELLUM_CORTEX_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CEREBELLUM_WHITE_MATTER_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CEREBELLUM_WHITE_MATTER_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CEREBRAL_WHITE_MATTER_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CEREBRAL_WHITE_MATTER_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CHOROID_PLEXUS_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_CHOROID_PLEXUS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_HIPPOCAMPUS_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_HIPPOCAMPUS_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_INF_LAT_VENT_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_INF_LAT_VENT_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_LATERAL_VENTRICLE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_LATERAL_VENTRICLE_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_PALLIDUM_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_PALLIDUM_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_PUTAMEN_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_PUTAMEN_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_THALAMUS_PROPER_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_THALAMUS_PROPER_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_VENTRALDC_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_VENTRALDC_SIZE_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_VESSEL_UCBERKELEYAV1451_10_17_16',
#  'RIGHT_VESSEL_SIZE_UCBERKELEYAV1451_10_17_16',
#  'WM_HYPOINTENSITIES_UCBERKELEYAV1451_10_17_16',
#  'WM_HYPOINTENSITIES_SIZE_UCBERKELEYAV1451_10_17_16',
#  'update_stamp_UCBERKELEYAV1451_10_17_16',
#  'VERSION_DTIROI_04_30_14',
#  'VISITNO_DTIROI_04_30_14',
#  'LONIUID_1_DTIROI_04_30_14',
#  'LONIUID_2_DTIROI_04_30_14',
#  'LONIUID_3_DTIROI_04_30_14',
#  'LONIUID_4_DTIROI_04_30_14',
#  'FA_CST_L_DTIROI_04_30_14',
#  'FA_CST_R_DTIROI_04_30_14',
#  'FA_ICP_L_DTIROI_04_30_14',
#  'FA_ICP_R_DTIROI_04_30_14',
#  'FA_ML_L_DTIROI_04_30_14',
#  'FA_ML_R_DTIROI_04_30_14',
#  'FA_SCP_L_DTIROI_04_30_14',
#  'FA_SCP_R_DTIROI_04_30_14',
#  'FA_CP_L_DTIROI_04_30_14',
#  'FA_CP_R_DTIROI_04_30_14',
#  'FA_ALIC_L_DTIROI_04_30_14',
#  'FA_ALIC_R_DTIROI_04_30_14',
#  'FA_PLIC_L_DTIROI_04_30_14',
#  'FA_PLIC_R_DTIROI_04_30_14',
#  'FA_PTR_L_DTIROI_04_30_14',
#  'FA_PTR_R_DTIROI_04_30_14',
#  'FA_ACR_L_DTIROI_04_30_14',
#  'FA_ACR_R_DTIROI_04_30_14',
#  'FA_SCR_L_DTIROI_04_30_14',
#  'FA_SCR_R_DTIROI_04_30_14',
#  'FA_PCR_L_DTIROI_04_30_14',
#  'FA_PCR_R_DTIROI_04_30_14',
#  'FA_CGC_L_DTIROI_04_30_14',
#  'FA_CGC_R_DTIROI_04_30_14',
#  'FA_CGH_L_DTIROI_04_30_14',
#  'FA_CGH_R_DTIROI_04_30_14',
#  'FA_FX_ST_L_DTIROI_04_30_14',
#  'FA_FX_ST_R_DTIROI_04_30_14',
#  'FA_SLF_L_DTIROI_04_30_14',
#  'FA_SLF_R_DTIROI_04_30_14',
#  'FA_SFO_L_DTIROI_04_30_14',
#  'FA_SFO_R_DTIROI_04_30_14',
#  'FA_IFO_L_DTIROI_04_30_14',
#  'FA_IFO_R_DTIROI_04_30_14',
#  'FA_SS_L_DTIROI_04_30_14',
#  'FA_SS_R_DTIROI_04_30_14',
#  'FA_EC_L_DTIROI_04_30_14',
#  'FA_EC_R_DTIROI_04_30_14',
#  'FA_UNC_L_DTIROI_04_30_14',
#  'FA_UNC_R_DTIROI_04_30_14',
#  'FA_FX_L_DTIROI_04_30_14',
#  'FA_FX_R_DTIROI_04_30_14',
#  'FA_GCC_L_DTIROI_04_30_14',
#  'FA_GCC_R_DTIROI_04_30_14',
#  'FA_BCC_L_DTIROI_04_30_14',
#  'FA_BCC_R_DTIROI_04_30_14',
#  'FA_SCC_L_DTIROI_04_30_14',
#  'FA_SCC_R_DTIROI_04_30_14',
#  'FA_RLIC_L_DTIROI_04_30_14',
#  'FA_RLIC_R_DTIROI_04_30_14',
#  'FA_TAP_L_DTIROI_04_30_14',
#  'FA_TAP_R_DTIROI_04_30_14',
#  'FA_SUMGCC_DTIROI_04_30_14',
#  'FA_SUMBCC_DTIROI_04_30_14',
#  'FA_SUMSCC_DTIROI_04_30_14',
#  'FA_SUMCC_DTIROI_04_30_14',
#  'FA_SUMFX_DTIROI_04_30_14',
#  'MD_CST_L_DTIROI_04_30_14',
#  'MD_CST_R_DTIROI_04_30_14',
#  'MD_ICP_L_DTIROI_04_30_14',
#  'MD_ICP_R_DTIROI_04_30_14',
#  'MD_ML_L_DTIROI_04_30_14',
#  'MD_ML_R_DTIROI_04_30_14',
#  'MD_SCP_L_DTIROI_04_30_14',
#  'MD_SCP_R_DTIROI_04_30_14',
#  'MD_CP_L_DTIROI_04_30_14',
#  'MD_CP_R_DTIROI_04_30_14',
#  'MD_ALIC_L_DTIROI_04_30_14',
#  'MD_ALIC_R_DTIROI_04_30_14',
#  'MD_PLIC_L_DTIROI_04_30_14',
#  'MD_PLIC_R_DTIROI_04_30_14',
#  'MD_PTR_L_DTIROI_04_30_14',
#  'MD_PTR_R_DTIROI_04_30_14',
#  'MD_ACR_L_DTIROI_04_30_14',
#  'MD_ACR_R_DTIROI_04_30_14',
#  'MD_SCR_L_DTIROI_04_30_14',
#  'MD_SCR_R_DTIROI_04_30_14',
#  'MD_PCR_L_DTIROI_04_30_14',
#  'MD_PCR_R_DTIROI_04_30_14',
#  'MD_CGC_L_DTIROI_04_30_14',
#  'MD_CGC_R_DTIROI_04_30_14',
#  'MD_CGH_L_DTIROI_04_30_14',
#  'MD_CGH_R_DTIROI_04_30_14',
#  'MD_FX_ST_L_DTIROI_04_30_14',
#  'MD_FX_ST_R_DTIROI_04_30_14',
#  'MD_SLF_L_DTIROI_04_30_14',
#  'MD_SLF_R_DTIROI_04_30_14',
#  'MD_SFO_L_DTIROI_04_30_14',
#  'MD_SFO_R_DTIROI_04_30_14',
#  'MD_IFO_L_DTIROI_04_30_14',
#  'MD_IFO_R_DTIROI_04_30_14',
#  'MD_SS_L_DTIROI_04_30_14',
#  'MD_SS_R_DTIROI_04_30_14',
#  'MD_EC_L_DTIROI_04_30_14',
#  'MD_EC_R_DTIROI_04_30_14',
#  'MD_UNC_L_DTIROI_04_30_14',
#  'MD_UNC_R_DTIROI_04_30_14',
#  'MD_FX_L_DTIROI_04_30_14',
#  'MD_FX_R_DTIROI_04_30_14',
#  'MD_GCC_L_DTIROI_04_30_14',
#  'MD_GCC_R_DTIROI_04_30_14',
#  'MD_BCC_L_DTIROI_04_30_14',
#  'MD_BCC_R_DTIROI_04_30_14',
#  'MD_SCC_L_DTIROI_04_30_14',
#  'MD_SCC_R_DTIROI_04_30_14',
#  'MD_RLIC_L_DTIROI_04_30_14',
#  'MD_RLIC_R_DTIROI_04_30_14',
#  'MD_TAP_L_DTIROI_04_30_14',
#  'MD_TAP_R_DTIROI_04_30_14',
#  'MD_SUMGCC_DTIROI_04_30_14',
#  'MD_SUMBCC_DTIROI_04_30_14',
#  'MD_SUMSCC_DTIROI_04_30_14',
#  'MD_SUMCC_DTIROI_04_30_14',
#  'MD_SUMFX_DTIROI_04_30_14',
#  'RD_CST_L_DTIROI_04_30_14',
#  'RD_CST_R_DTIROI_04_30_14',
#  'RD_ICP_L_DTIROI_04_30_14',
#  'RD_ICP_R_DTIROI_04_30_14',
#  'RD_ML_L_DTIROI_04_30_14',
#  'RD_ML_R_DTIROI_04_30_14',
#  'RD_SCP_L_DTIROI_04_30_14',
#  'RD_SCP_R_DTIROI_04_30_14',
#  'RD_CP_L_DTIROI_04_30_14',
#  'RD_CP_R_DTIROI_04_30_14',
#  'RD_ALIC_L_DTIROI_04_30_14',
#  'RD_ALIC_R_DTIROI_04_30_14',
#  'RD_PLIC_L_DTIROI_04_30_14',
#  'RD_PLIC_R_DTIROI_04_30_14',
#  'RD_PTR_L_DTIROI_04_30_14',
#  'RD_PTR_R_DTIROI_04_30_14',
#  'RD_ACR_L_DTIROI_04_30_14',
#  'RD_ACR_R_DTIROI_04_30_14',
#  'RD_SCR_L_DTIROI_04_30_14',
#  'RD_SCR_R_DTIROI_04_30_14',
#  'RD_PCR_L_DTIROI_04_30_14',
#  'RD_PCR_R_DTIROI_04_30_14',
#  'RD_CGC_L_DTIROI_04_30_14',
#  'RD_CGC_R_DTIROI_04_30_14',
#  'RD_CGH_L_DTIROI_04_30_14',
#  'RD_CGH_R_DTIROI_04_30_14',
#  'RD_FX_ST_L_DTIROI_04_30_14',
#  'RD_FX_ST_R_DTIROI_04_30_14',
#  'RD_SLF_L_DTIROI_04_30_14',
#  'RD_SLF_R_DTIROI_04_30_14',
#  'RD_SFO_L_DTIROI_04_30_14',
#  'RD_SFO_R_DTIROI_04_30_14',
#  'RD_IFO_L_DTIROI_04_30_14',
#  'RD_IFO_R_DTIROI_04_30_14',
#  'RD_SS_L_DTIROI_04_30_14',
#  'RD_SS_R_DTIROI_04_30_14',
#  'RD_EC_L_DTIROI_04_30_14',
#  'RD_EC_R_DTIROI_04_30_14',
#  'RD_UNC_L_DTIROI_04_30_14',
#  'RD_UNC_R_DTIROI_04_30_14',
#  'RD_FX_L_DTIROI_04_30_14',
#  'RD_FX_R_DTIROI_04_30_14',
#  'RD_GCC_L_DTIROI_04_30_14',
#  'RD_GCC_R_DTIROI_04_30_14',
#  'RD_BCC_L_DTIROI_04_30_14',
#  'RD_BCC_R_DTIROI_04_30_14',
#  'RD_SCC_L_DTIROI_04_30_14',
#  'RD_SCC_R_DTIROI_04_30_14',
#  'RD_RLIC_L_DTIROI_04_30_14',
#  'RD_RLIC_R_DTIROI_04_30_14',
#  'RD_TAP_L_DTIROI_04_30_14',
#  'RD_TAP_R_DTIROI_04_30_14',
#  'RD_SUMGCC_DTIROI_04_30_14',
#  'RD_SUMBCC_DTIROI_04_30_14',
#  'RD_SUMSCC_DTIROI_04_30_14',
#  'RD_SUMCC_DTIROI_04_30_14',
#  'RD_SUMFX_DTIROI_04_30_14',
#  'AD_CST_L_DTIROI_04_30_14',
#  'AD_CST_R_DTIROI_04_30_14',
#  'AD_ICP_L_DTIROI_04_30_14',
#  'AD_ICP_R_DTIROI_04_30_14',
#  'AD_ML_L_DTIROI_04_30_14',
#  'AD_ML_R_DTIROI_04_30_14',
#  'AD_SCP_L_DTIROI_04_30_14',
#  'AD_SCP_R_DTIROI_04_30_14',
#  'AD_CP_L_DTIROI_04_30_14',
#  'AD_CP_R_DTIROI_04_30_14',
#  'AD_ALIC_L_DTIROI_04_30_14',
#  'AD_ALIC_R_DTIROI_04_30_14',
#  'AD_PLIC_L_DTIROI_04_30_14',
#  'AD_PLIC_R_DTIROI_04_30_14',
#  'AD_PTR_L_DTIROI_04_30_14',
#  'AD_PTR_R_DTIROI_04_30_14',
#  'AD_ACR_L_DTIROI_04_30_14',
#  'AD_ACR_R_DTIROI_04_30_14',
#  'AD_SCR_L_DTIROI_04_30_14',
#  'AD_SCR_R_DTIROI_04_30_14',
#  'AD_PCR_L_DTIROI_04_30_14',
#  'AD_PCR_R_DTIROI_04_30_14',
#  'AD_CGC_L_DTIROI_04_30_14',
#  'AD_CGC_R_DTIROI_04_30_14',
#  'AD_CGH_L_DTIROI_04_30_14',
#  'AD_CGH_R_DTIROI_04_30_14',
#  'AD_FX_ST_L_DTIROI_04_30_14',
#  'AD_FX_ST_R_DTIROI_04_30_14',
#  'AD_SLF_L_DTIROI_04_30_14',
#  'AD_SLF_R_DTIROI_04_30_14',
#  'AD_SFO_L_DTIROI_04_30_14',
#  'AD_SFO_R_DTIROI_04_30_14',
#  'AD_IFO_L_DTIROI_04_30_14',
#  'AD_IFO_R_DTIROI_04_30_14',
#  'AD_SS_L_DTIROI_04_30_14',
#  'AD_SS_R_DTIROI_04_30_14',
#  'AD_EC_L_DTIROI_04_30_14',
#  'AD_EC_R_DTIROI_04_30_14',
#  'AD_UNC_L_DTIROI_04_30_14',
#  'AD_UNC_R_DTIROI_04_30_14',
#  'AD_FX_L_DTIROI_04_30_14',
#  'AD_FX_R_DTIROI_04_30_14',
#  'AD_GCC_L_DTIROI_04_30_14',
#  'AD_GCC_R_DTIROI_04_30_14',
#  'AD_BCC_L_DTIROI_04_30_14',
#  'AD_BCC_R_DTIROI_04_30_14',
#  'AD_SCC_L_DTIROI_04_30_14',
#  'AD_SCC_R_DTIROI_04_30_14',
#  'AD_RLIC_L_DTIROI_04_30_14',
#  'AD_RLIC_R_DTIROI_04_30_14',
#  'AD_TAP_L_DTIROI_04_30_14',
#  'AD_TAP_R_DTIROI_04_30_14',
#  'AD_SUMGCC_DTIROI_04_30_14',
#  'AD_SUMBCC_DTIROI_04_30_14',
#  'AD_SUMSCC_DTIROI_04_30_14',
#  'AD_SUMCC_DTIROI_04_30_14',
#  'AD_SUMFX_DTIROI_04_30_14']

# %%
# create a new df with values to interpolate
good_df = df[df.columns[good_idx]]

# %%
for col in df.columns[:10]:
    good_df[col] = df[col]
# Out:
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
good_df.shape
# Out:
# (12741, 1385)

# %%
good_df
# Out:
#       DX_bl  DXCHANGE   AGE  PTGENDER  PTEDUCAT  PTETHCAT  PTRACCAT  PTMARRY  \
# 0        CN       1.0  74.3         1        16         1         1        1
# 1        AD       3.0  81.3         1        18         1         1        1
# 2        AD       3.0  81.3         1        18         1         1        1
# 3        AD       3.0  81.3         1        18         1         1        1
# 4        AD       3.0  81.3         1        18         1         1        1
# 5      LMCI       2.0  67.5         1        10         2         1        1
# 6      LMCI       2.0  67.5         1        10         2         1        1
# 7      LMCI       2.0  67.5         1        10         2         1        1
# 8      LMCI       2.0  67.5         1        10         2         1        1
# 9      LMCI       2.0  67.5         1        10         2         1        1
# 10       CN       1.0  73.7         1        16         1         1        1
# 11       CN       1.0  73.7         1        16         1         1        1
# 12       CN       1.0  73.7         1        16         1         1        1
# 13       CN       1.0  73.7         1        16         1         1        1
# 14       CN       1.0  73.7         1        16         1         1        1
# 15     LMCI       2.0  80.4         2        13         1         1        1
# 16     LMCI       2.0  80.4         2        13         1         1        1
# 17     LMCI       2.0  80.4         2        13         1         1        1
# 18     LMCI       2.0  80.4         2        13         1         1        1
# 19     LMCI       2.0  80.4         2        13         1         1        1
# 20       AD       3.0  75.4         1        10         2         2        1
# 21       AD       3.0  75.4         1        10         2         2        1
# 22       CN       1.0  84.5         2        18         1         1        2
# 23       CN       1.0  84.5         2        18         1         1        2
# 24       AD       3.0  73.9         2        12         1         1        1
# 25       AD       3.0  73.9         2        12         1         1        1
# 26       AD       3.0  73.9         2        12         1         1        1
# 27       AD       3.0  73.9         2        12         1         1        1
# 28       CN       1.0  78.5         2        12         2         1        3
# 29       CN       1.0  78.5         2        12         2         1        3
# ...     ...       ...   ...       ...       ...       ...       ...      ...
# 12711  LMCI       5.0  84.7         2        14         1         1        2
# 12712  EMCI       2.0  68.2         1        16         1         1        1
# 12713  EMCI       2.0  68.0         2        16         1         1        3
# 12714  LMCI       NaN  62.4         1        18         1         1        1
# 12715  LMCI       NaN  72.4         1        12         1         1        1
# 12716  EMCI       2.0  74.6         1        18         1         1        1
# 12717    CN       2.0  76.8         1        16         1         1        1
# 12718  EMCI       NaN  73.1         1        20         1         1        1
# 12719    CN       5.0  72.0         2        15         1         1        1
# 12720    CN       NaN  65.8         2        15         2         1        1
# 12721  EMCI       NaN  82.3         2        14         1         1        1
# 12722  EMCI       1.0  63.6         2        16         1         1        1
# 12723  EMCI       2.0  81.4         2        18         1         1        1
# 12724  EMCI       2.0  68.1         1        20         1         1        1
# 12725    CN       8.0  77.0         1        16         1         1        1
# 12726    CN       1.0  77.1         2        18         1         1        1
# 12727   SMC       4.0  75.2         2        18         1         1        1
# 12728  LMCI       5.0  84.7         1        18         1         1        1
# 12729  LMCI       NaN  70.9         2        17         1         3        1
# 12730  LMCI       2.0  79.1         1        10         1         1        1
# 12731    CN       1.0  75.5         2        19         1         1        3
# 12732  EMCI       NaN  69.9         1        20         1         1        1
# 12733  EMCI       2.0  66.0         2        16         1         1        1
# 12734  EMCI       1.0  72.9         1        20         1         4        4
# 12735  EMCI       NaN  65.5         1        13         1         1        1
# 12736  LMCI       NaN  69.5         2        16         1         1        1
# 12737  EMCI       NaN  59.0         1        16         1         1        1
# 12738  EMCI       NaN  83.3         2        12         1         1        2
# 12739  EMCI       NaN  68.0         2        16         1         1        1
# 12740  EMCI       NaN  67.8         1        16         1         1        3
#
#        APOE4       FDG     ...      Unnamed: 0   RID        PTID  VISCODE  \
# 0        0.0  1.369260     ...               0     2  011_S_0002       bl
# 1        1.0  1.090790     ...               1     3  011_S_0003       bl
# 2        1.0  1.063600     ...               2     3  011_S_0003      m06
# 3        1.0  1.103840     ...               3     3  011_S_0003      m12
# 4        1.0  1.038710     ...               4     3  011_S_0003      m24
# 5        0.0       NaN     ...               5     4  022_S_0004       bl
# 6        0.0       NaN     ...               6     4  022_S_0004      m06
# 7        0.0       NaN     ...               7     4  022_S_0004      m12
# 8        0.0       NaN     ...               8     4  022_S_0004      m18
# 9        0.0       NaN     ...               9     4  022_S_0004      m36
# 10       0.0  1.297990     ...              10     5  011_S_0005       bl
# 11       0.0  1.306170     ...              11     5  011_S_0005      m06
# 12       0.0  1.284740     ...              12     5  011_S_0005      m12
# 13       0.0  1.367420     ...              13     5  011_S_0005      m24
# 14       0.0  1.342130     ...              14     5  011_S_0005      m36
# 15       0.0       NaN     ...              15     6  100_S_0006       bl
# 16       0.0       NaN     ...              16     6  100_S_0006      m06
# 17       0.0       NaN     ...              17     6  100_S_0006      m12
# 18       0.0       NaN     ...              18     6  100_S_0006      m18
# 19       0.0       NaN     ...              19     6  100_S_0006      m36
# 20       1.0       NaN     ...              20     7  022_S_0007       bl
# 21       1.0       NaN     ...              21     7  022_S_0007      m06
# 22       0.0  1.276280     ...              22     8  011_S_0008       bl
# 23       0.0  1.285680     ...              23     8  011_S_0008      m06
# 24       1.0  1.118810     ...              24    10  011_S_0010       bl
# 25       1.0  1.079790     ...              25    10  011_S_0010      m06
# 26       1.0  1.010140     ...              26    10  011_S_0010      m12
# 27       1.0  0.961136     ...              27    10  011_S_0010      m24
# 28       0.0  1.256990     ...              28    14  022_S_0014       bl
# 29       0.0  1.353580     ...              29    14  022_S_0014      m06
# ...      ...       ...     ...             ...   ...         ...      ...
# 12711    0.0       NaN     ...           12711  4777  073_S_4777      m48
# 12712    1.0       NaN     ...           12712  4309  135_S_4309      m60
# 12713    0.0       NaN     ...           12713  2407  126_S_2407      m60
# 12714    1.0       NaN     ...           12714   919  053_S_0919     m120
# 12715    0.0       NaN     ...           12715   945  036_S_0945     m108
# 12716    0.0       NaN     ...           12716  4301  127_S_4301      m60
# 12717    0.0       NaN     ...           12717   896  098_S_0896     m120
# 12718    0.0       NaN     ...           12718  2052  098_S_2052      m72
# 12719    1.0       NaN     ...           12719  1098  033_S_1098     m120
# 12720    1.0       NaN     ...           12720  4555  003_S_4555      m48
# 12721    0.0       NaN     ...           12721  2213  127_S_2213      m72
# 12722    0.0       NaN     ...           12722  2234  127_S_2234      m72
# 12723    0.0       NaN     ...           12723  4205  099_S_4205      m60
# 12724    0.0       NaN     ...           12724  4356  135_S_4356      m60
# 12725    1.0       NaN     ...           12725   555  035_S_0555     m120
# 12726    1.0       NaN     ...           12726  1023  036_S_1023     m108
# 12727    1.0       NaN     ...           12727  5263  032_S_5263      m24
# 12728    1.0       NaN     ...           12728  1032  127_S_1032     m120
# 12729    1.0       NaN     ...           12729  4287  129_S_4287      m60
# 12730    0.0       NaN     ...           12730   296  100_S_0296     m120
# 12731    0.0       NaN     ...           12731  1286  100_S_1286     m108
# 12732    0.0       NaN     ...           12732  4621  153_S_4621      m48
# 12733    0.0       NaN     ...           12733  2061  035_S_2061      m72
# 12734    0.0       NaN     ...           12734  4556  100_S_4556      m48
# 12735    0.0       NaN     ...           12735  2079  098_S_2079      m72
# 12736    1.0       NaN     ...           12736  4167  116_S_4167      m60
# 12737    0.0       NaN     ...           12737  4199  116_S_4199      m60
# 12738    0.0       NaN     ...           12738  4557  053_S_4557      m60
# 12739    0.0       NaN     ...           12739  4512  100_S_4512      m48
# 12740    2.0       NaN     ...           12740  2380  036_S_2380      m72
#
#        SITE  D1  D2  COLPROT  ORIGPROT    EXAMDATE
# 0        11   1   1    ADNI1     ADNI1  2005-09-08
# 1        11   1   0    ADNI1     ADNI1  2005-09-12
# 2        11   1   0    ADNI1     ADNI1  2006-03-13
# 3        11   1   0    ADNI1     ADNI1  2006-09-12
# 4        11   1   0    ADNI1     ADNI1  2007-09-12
# 5        22   1   0    ADNI1     ADNI1  2005-11-08
# 6        22   1   0    ADNI1     ADNI1  2006-05-02
# 7        22   1   0    ADNI1     ADNI1  2006-11-14
# 8        22   1   0    ADNI1     ADNI1  2007-05-14
# 9        22   1   0    ADNI1     ADNI1  2008-11-18
# 10       11   1   0    ADNI1     ADNI1  2005-09-07
# 11       11   1   0    ADNI1     ADNI1  2006-03-09
# 12       11   1   0    ADNI1     ADNI1  2006-09-05
# 13       11   1   0    ADNI1     ADNI1  2007-09-07
# 14       11   1   0    ADNI1     ADNI1  2008-09-10
# 15      100   1   0    ADNI1     ADNI1  2005-11-29
# 16      100   1   0    ADNI1     ADNI1  2006-06-01
# 17      100   1   0    ADNI1     ADNI1  2006-11-20
# 18      100   1   0    ADNI1     ADNI1  2007-05-15
# 19      100   1   0    ADNI1     ADNI1  2008-12-08
# 20       22   1   0    ADNI1     ADNI1  2005-10-06
# 21       22   1   0    ADNI1     ADNI1  2006-04-13
# 22       11   1   1    ADNI1     ADNI1  2005-09-19
# 23       11   1   1    ADNI1     ADNI1  2006-03-20
# 24       11   1   0    ADNI1     ADNI1  2005-11-10
# 25       11   1   0    ADNI1     ADNI1  2006-05-09
# 26       11   1   0    ADNI1     ADNI1  2006-11-09
# 27       11   1   0    ADNI1     ADNI1  2007-11-07
# 28       22   1   0    ADNI1     ADNI1  2005-11-04
# 29       22   1   0    ADNI1     ADNI1  2006-05-02
# ...     ...  ..  ..      ...       ...         ...
# 12711    73   1   1    ADNI2     ADNI2  2016-11-16
# 12712   135   1   1    ADNI2     ADNI2  2016-11-29
# 12713   126   1   1    ADNI2    ADNIGO  2016-11-22
# 12714    53   1   1    ADNI2     ADNI1  2016-11-10
# 12715    36   1   0    ADNI2     ADNI1  2016-11-22
# 12716   127   1   1    ADNI2     ADNI2  2016-11-17
# 12717    98   1   1    ADNI2     ADNI1  2016-11-16
# 12718    98   1   1    ADNI2    ADNIGO  2016-11-30
# 12719    33   1   1    ADNI2     ADNI1  2016-12-06
# 12720     3   1   1    ADNI2     ADNI2  2016-04-22
# 12721   127   1   1    ADNI2    ADNIGO  2016-12-08
# 12722   127   1   1    ADNI2    ADNIGO  2016-12-09
# 12723    99   1   1    ADNI2     ADNI2  2016-12-08
# 12724   135   1   1    ADNI2     ADNI2  2016-12-12
# 12725    35   1   1    ADNI2     ADNI1  2016-12-14
# 12726    36   1   1    ADNI2     ADNI1  2017-01-10
# 12727    32   1   0    ADNI2     ADNI2  2017-01-17
# 12728   127   1   1    ADNI2     ADNI1  2016-11-30
# 12729   129   1   1    ADNI2     ADNI2  2016-10-28
# 12730   100   1   1    ADNI2     ADNI1  2017-01-24
# 12731   100   1   1    ADNI2     ADNI1  2017-01-25
# 12732   153   1   1    ADNI2     ADNI2  2016-04-25
# 12733    35   1   1    ADNI2    ADNIGO  2016-09-14
# 12734   100   1   1    ADNI2     ADNI2  2017-01-30
# 12735    98   1   1    ADNI2    ADNIGO  2016-12-12
# 12736   116   1   1    ADNI2     ADNI2  2016-11-16
# 12737   116   1   1    ADNI2     ADNI2  2016-12-12
# 12738    53   1   1    ADNI2     ADNI2  2017-03-15
# 12739   100   1   1    ADNI2     ADNI2  2017-04-04
# 12740    36   1   1    ADNI2    ADNIGO  2017-05-05
#
# [12741 rows x 1385 columns]

# %%
# scale the data, being sure to avoid NaNs, but also accurately remap to the data
for i,col in enumerate(good_df.columns[1:-10]):
    print('working on %s of %s'%(i,good_df.shape[-1]))
    if col == 'ventr_ICV_ratio':
        to_scale = good_df[col].dropna(axis=0)
        scaler = FunctionTransformer(np.log).fit(to_scale)
        good_df.loc[to_scale.index,col] = scaler.transform(good_df.loc[to_scale.index,col])
    to_scale = good_df[col].dropna(axis=0)
    scaler = StandardScaler().fit(to_scale)
    good_df.loc[to_scale.index,col] = scaler.transform(good_df.loc[to_scale.index,col])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-17c25107be98> in <module>()
#       1 # scale the data, being sure to avoid NaNs, but also accurately remap to the data
# ----> 2 for i,col in enumerate(good_df.columns[1:-10]):
#       3     print('working on %s of %s'%(i,good_df.shape[-1]))
#       4     if col == 'ventr_ICV_ratio':
#       5         to_scale = good_df[col].dropna(axis=0)
#
# NameError: name 'good_df' is not defined

# %%
# IMPUTE THE DATAAAAA ... P.S. this is the simplest imputation and it took about 45 minutes to run
dat_filled = fi.KNN().complete(good_df[good_df.columns[1:-10]])
# Out:
# Imputing row 1/12741 with 618 missing, elapsed time: 1530.918
# Imputing row 101/12741 with 609 missing, elapsed time: 1539.384
# Imputing row 201/12741 with 280 missing, elapsed time: 1547.837
# Imputing row 301/12741 with 611 missing, elapsed time: 1557.545
# Imputing row 401/12741 with 277 missing, elapsed time: 1565.716
# Imputing row 501/12741 with 611 missing, elapsed time: 1574.869
# Imputing row 601/12741 with 608 missing, elapsed time: 1582.506
# Imputing row 701/12741 with 278 missing, elapsed time: 1589.777
# Imputing row 801/12741 with 953 missing, elapsed time: 1597.127
# Imputing row 901/12741 with 280 missing, elapsed time: 1605.015
# Imputing row 1001/12741 with 280 missing, elapsed time: 1613.506
# Imputing row 1101/12741 with 617 missing, elapsed time: 1622.836
# Imputing row 1201/12741 with 946 missing, elapsed time: 1629.868
# Imputing row 1301/12741 with 278 missing, elapsed time: 1636.828
# Imputing row 1401/12741 with 608 missing, elapsed time: 1644.123
# Imputing row 1501/12741 with 617 missing, elapsed time: 1650.138
# Imputing row 1601/12741 with 607 missing, elapsed time: 1656.578
# Imputing row 1701/12741 with 276 missing, elapsed time: 1662.414
# Imputing row 1801/12741 with 609 missing, elapsed time: 1668.228
# Imputing row 1901/12741 with 277 missing, elapsed time: 1674.799
# Imputing row 2001/12741 with 278 missing, elapsed time: 1681.896
# Imputing row 2101/12741 with 690 missing, elapsed time: 1688.054
# Imputing row 2201/12741 with 949 missing, elapsed time: 1693.866
# Imputing row 2301/12741 with 618 missing, elapsed time: 1699.999
# Imputing row 2401/12741 with 280 missing, elapsed time: 1706.283
# Imputing row 2501/12741 with 611 missing, elapsed time: 1712.478
# Imputing row 2601/12741 with 608 missing, elapsed time: 1719.111
# Imputing row 2701/12741 with 933 missing, elapsed time: 1725.419
# Imputing row 2801/12741 with 276 missing, elapsed time: 1732.139
# Imputing row 2901/12741 with 607 missing, elapsed time: 1739.233
# Imputing row 3001/12741 with 621 missing, elapsed time: 1745.409
# Imputing row 3101/12741 with 357 missing, elapsed time: 1751.128
# Imputing row 3201/12741 with 359 missing, elapsed time: 1759.228
# Imputing row 3301/12741 with 953 missing, elapsed time: 1766.020
# Imputing row 3401/12741 with 957 missing, elapsed time: 1774.346
# Imputing row 3501/12741 with 358 missing, elapsed time: 1782.270
# Imputing row 3601/12741 with 611 missing, elapsed time: 1788.717
# Imputing row 3701/12741 with 927 missing, elapsed time: 1795.337
# Imputing row 3801/12741 with 954 missing, elapsed time: 1802.587
# Imputing row 3901/12741 with 927 missing, elapsed time: 1811.336
# Imputing row 4001/12741 with 927 missing, elapsed time: 1820.463
# Imputing row 4101/12741 with 636 missing, elapsed time: 1829.232
# Imputing row 4201/12741 with 612 missing, elapsed time: 1837.345
# Imputing row 4301/12741 with 952 missing, elapsed time: 1846.496
# Imputing row 4401/12741 with 612 missing, elapsed time: 1855.148
# Imputing row 4501/12741 with 929 missing, elapsed time: 1863.951
# Imputing row 4601/12741 with 681 missing, elapsed time: 1872.843
# Imputing row 4701/12741 with 952 missing, elapsed time: 1882.729
# Imputing row 4801/12741 with 953 missing, elapsed time: 1891.670
# Imputing row 4901/12741 with 635 missing, elapsed time: 1899.484
# Imputing row 5001/12741 with 385 missing, elapsed time: 1906.451
# Imputing row 5101/12741 with 953 missing, elapsed time: 1914.877
# Imputing row 5201/12741 with 682 missing, elapsed time: 1923.400
# Imputing row 5301/12741 with 611 missing, elapsed time: 1930.799
# Imputing row 5401/12741 with 682 missing, elapsed time: 1938.330
# Imputing row 5501/12741 with 682 missing, elapsed time: 1945.833
# Imputing row 5601/12741 with 611 missing, elapsed time: 1954.249
# Imputing row 5701/12741 with 363 missing, elapsed time: 1962.419
# Imputing row 5801/12741 with 281 missing, elapsed time: 1973.942
# Imputing row 5901/12741 with 1293 missing, elapsed time: 1985.840
# Imputing row 6001/12741 with 1274 missing, elapsed time: 1998.707
# Imputing row 6101/12741 with 1293 missing, elapsed time: 2010.736
# Imputing row 6201/12741 with 1297 missing, elapsed time: 2022.058
# Imputing row 6301/12741 with 1292 missing, elapsed time: 2033.761
# Imputing row 6401/12741 with 1297 missing, elapsed time: 2044.986
# Imputing row 6501/12741 with 957 missing, elapsed time: 2056.826
# Imputing row 6601/12741 with 1297 missing, elapsed time: 2067.861
# Imputing row 6701/12741 with 1287 missing, elapsed time: 2078.509
# Imputing row 6801/12741 with 1297 missing, elapsed time: 2090.435
# Imputing row 6901/12741 with 282 missing, elapsed time: 2101.649
# Imputing row 7001/12741 with 954 missing, elapsed time: 2113.565
# Imputing row 7101/12741 with 284 missing, elapsed time: 2125.261
# Imputing row 7201/12741 with 1296 missing, elapsed time: 2136.708
# Imputing row 7301/12741 with 1296 missing, elapsed time: 2148.568
# Imputing row 7401/12741 with 613 missing, elapsed time: 2159.850
# Imputing row 7501/12741 with 955 missing, elapsed time: 2171.664
# Imputing row 7601/12741 with 1296 missing, elapsed time: 2182.772
# Imputing row 7701/12741 with 1297 missing, elapsed time: 2194.361
# Imputing row 7801/12741 with 1292 missing, elapsed time: 2205.441
# Imputing row 7901/12741 with 1297 missing, elapsed time: 2216.992
# Imputing row 8001/12741 with 1293 missing, elapsed time: 2228.390
# Imputing row 8101/12741 with 1297 missing, elapsed time: 2239.861
# Imputing row 8201/12741 with 1297 missing, elapsed time: 2251.251
# Imputing row 8301/12741 with 954 missing, elapsed time: 2264.137
# Imputing row 8401/12741 with 1298 missing, elapsed time: 2276.800
# Imputing row 8501/12741 with 1289 missing, elapsed time: 2288.859
# Imputing row 8601/12741 with 1301 missing, elapsed time: 2300.610
# Imputing row 8701/12741 with 613 missing, elapsed time: 2312.657
# Imputing row 8801/12741 with 1291 missing, elapsed time: 2325.213
# Imputing row 8901/12741 with 280 missing, elapsed time: 2336.555
# Imputing row 9001/12741 with 1294 missing, elapsed time: 2347.138
# Imputing row 9101/12741 with 953 missing, elapsed time: 2358.691
# Imputing row 9201/12741 with 1274 missing, elapsed time: 2370.760
# Imputing row 9301/12741 with 928 missing, elapsed time: 2382.723
# Imputing row 9401/12741 with 1279 missing, elapsed time: 2394.669
# Imputing row 9501/12741 with 1276 missing, elapsed time: 2406.392
# Imputing row 9601/12741 with 1277 missing, elapsed time: 2418.461
# Imputing row 9701/12741 with 1276 missing, elapsed time: 2433.285
# Imputing row 9801/12741 with 1279 missing, elapsed time: 2444.656
# Imputing row 9901/12741 with 685 missing, elapsed time: 2455.918
# Imputing row 10001/12741 with 681 missing, elapsed time: 2467.309
# Imputing row 10101/12741 with 1276 missing, elapsed time: 2478.270
# Imputing row 10201/12741 with 934 missing, elapsed time: 2492.112
# Imputing row 10301/12741 with 1276 missing, elapsed time: 2504.919
# Imputing row 10401/12741 with 689 missing, elapsed time: 2515.922
# Imputing row 10501/12741 with 958 missing, elapsed time: 2526.137
# Imputing row 10601/12741 with 370 missing, elapsed time: 2535.006
# Imputing row 10701/12741 with 1251 missing, elapsed time: 2544.773
# Imputing row 10801/12741 with 692 missing, elapsed time: 2555.577
# Imputing row 10901/12741 with 1292 missing, elapsed time: 2566.626
# Imputing row 11001/12741 with 1251 missing, elapsed time: 2577.434
# Imputing row 11101/12741 with 684 missing, elapsed time: 2588.343
# Imputing row 11201/12741 with 685 missing, elapsed time: 2599.680
# Imputing row 11301/12741 with 1250 missing, elapsed time: 2610.550
# Imputing row 11401/12741 with 1292 missing, elapsed time: 2621.335
# Imputing row 11501/12741 with 1250 missing, elapsed time: 2632.952
# Imputing row 11601/12741 with 1276 missing, elapsed time: 2644.331
# Imputing row 11701/12741 with 1275 missing, elapsed time: 2656.849
# Imputing row 11801/12741 with 1258 missing, elapsed time: 2667.883
# Imputing row 11901/12741 with 1260 missing, elapsed time: 2679.085
# Imputing row 12001/12741 with 1034 missing, elapsed time: 2689.526
# Imputing row 12101/12741 with 376 missing, elapsed time: 2699.331
# Imputing row 12201/12741 with 1256 missing, elapsed time: 2710.792
# Imputing row 12301/12741 with 1256 missing, elapsed time: 2720.704
# Imputing row 12401/12741 with 1254 missing, elapsed time: 2733.037
# Imputing row 12501/12741 with 1012 missing, elapsed time: 2746.562
# Imputing row 12601/12741 with 1016 missing, elapsed time: 2759.840
# Imputing row 12701/12741 with 1265 missing, elapsed time: 2772.962

# %%
# Save imputed data into a dataframe
imp_df = pandas.DataFrame(dat_filled, columns = good_df.columns[1:-10])
for col in df.columns[:10]:
    imp_df[col] = df[col]
imp_df.to_csv('/Users/jakevogel/Science/TADPOLE/imputed_d1_d2.csv')

# %% [markdown]
# ### I'm going to now do the imputation with with less columns, but also with less missing values

# %%
# get indices of columns to keep, and columns to get rid of
bad_idx = [x+10 for x in range(len(missing)) if missing[x] > 0.5]
good_idx = [x+10 for x in range(len(missing)) if missing[x] < 0.5]

# %%
# how many left over?
len([x for x in range(len(missing)) if missing[x] < 0.5])
# Out:
# 383

# %%
good_df = df[df.columns[good_idx]]

# %%
for col in df.columns[:10]:
    good_df[col] = df[col]
# Out:
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
# scale the data, being sure to avoid NaNs, but also accurately remap to the data
for i,col in enumerate(good_df.columns[1:-10]):
    print('working on %s of %s'%(i,good_df.shape[-1]))
    to_scale = good_df[col].dropna(axis=0)
    scaler = StandardScaler().fit(to_scale)
    good_df.loc[to_scale.index,col] = scaler.transform(good_df.loc[to_scale.index,col])
# Out:
# working on 0 of 393
# working on 1 of 393
# working on 2 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 3 of 393
# working on 4 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 5 of 393
# working on 6 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 7 of 393
# working on 8 of 393
# working on 9 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 10 of 393
# working on 11 of 393
# working on 12 of 393
# working on 13 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 14 of 393
# working on 15 of 393
# working on 16 of 393
# working on 17 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 18 of 393
# working on 19 of 393
# working on 20 of 393
# working on 21 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 22 of 393
# working on 23 of 393
# working on 24 of 393
# working on 25 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 26 of 393
# working on 27 of 393
# working on 28 of 393
# working on 29 of 393
# working on 30 of 393
# working on 31 of 393
# working on 32 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 33 of 393
# working on 34 of 393
# working on 35 of 393
# working on 36 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 37 of 393
# working on 38 of 393
# working on 39 of 393
# working on 40 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 41 of 393
# working on 42 of 393
# working on 43 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 44 of 393
# working on 45 of 393
# working on 46 of 393
# working on 47 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 48 of 393
# working on 49 of 393
# working on 50 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 51 of 393
# working on 52 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 53 of 393
# working on 54 of 393
# working on 55 of 393
# working on 56 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 57 of 393
# working on 58 of 393
# working on 59 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 60 of 393
# working on 61 of 393
# working on 62 of 393
# ...
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 361 of 393
# working on 362 of 393
# working on 363 of 393
# working on 364 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 365 of 393
# working on 366 of 393
# working on 367 of 393
# working on 368 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 369 of 393
# working on 370 of 393
# working on 371 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 372 of 393
# working on 373 of 393
# working on 374 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 375 of 393
# working on 376 of 393
# working on 377 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 378 of 393
# working on 379 of 393
# working on 380 of 393
# working on 381 of 393
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
# IMPUTE THE DATAAAAA ... Using the new data cutoff, the inputation only took 11.4 minutes!
dat_filled50 = fi.KNN().complete(good_df[good_df.columns[1:-10]])
# Out:
# Imputing row 1/12741 with 0 missing, elapsed time: 440.085
# Imputing row 101/12741 with 1 missing, elapsed time: 440.107
# Imputing row 201/12741 with 0 missing, elapsed time: 440.132
# Imputing row 301/12741 with 1 missing, elapsed time: 440.215
# Imputing row 401/12741 with 0 missing, elapsed time: 440.236
# Imputing row 501/12741 with 1 missing, elapsed time: 440.273
# Imputing row 601/12741 with 0 missing, elapsed time: 440.333
# Imputing row 701/12741 with 0 missing, elapsed time: 440.373
# Imputing row 801/12741 with 5 missing, elapsed time: 440.431
# Imputing row 901/12741 with 0 missing, elapsed time: 440.478
# Imputing row 1001/12741 with 0 missing, elapsed time: 440.517
# Imputing row 1101/12741 with 0 missing, elapsed time: 440.603
# Imputing row 1201/12741 with 1 missing, elapsed time: 440.628
# Imputing row 1301/12741 with 0 missing, elapsed time: 440.656
# Imputing row 1401/12741 with 1 missing, elapsed time: 440.689
# Imputing row 1501/12741 with 0 missing, elapsed time: 440.722
# Imputing row 1601/12741 with 1 missing, elapsed time: 440.765
# Imputing row 1701/12741 with 0 missing, elapsed time: 440.792
# Imputing row 1801/12741 with 1 missing, elapsed time: 440.815
# Imputing row 1901/12741 with 0 missing, elapsed time: 440.856
# Imputing row 2001/12741 with 0 missing, elapsed time: 440.891
# Imputing row 2101/12741 with 0 missing, elapsed time: 440.917
# Imputing row 2201/12741 with 0 missing, elapsed time: 440.951
# Imputing row 2301/12741 with 0 missing, elapsed time: 440.973
# Imputing row 2401/12741 with 0 missing, elapsed time: 441.002
# Imputing row 2501/12741 with 1 missing, elapsed time: 441.033
# Imputing row 2601/12741 with 1 missing, elapsed time: 441.063
# Imputing row 2701/12741 with 1 missing, elapsed time: 441.094
# Imputing row 2801/12741 with 0 missing, elapsed time: 441.123
# Imputing row 2901/12741 with 1 missing, elapsed time: 441.149
# Imputing row 3001/12741 with 5 missing, elapsed time: 441.168
# Imputing row 3101/12741 with 2 missing, elapsed time: 441.194
# Imputing row 3201/12741 with 2 missing, elapsed time: 441.255
# Imputing row 3301/12741 with 12 missing, elapsed time: 441.319
# Imputing row 3401/12741 with 17 missing, elapsed time: 441.575
# Imputing row 3501/12741 with 2 missing, elapsed time: 441.649
# Imputing row 3601/12741 with 0 missing, elapsed time: 441.710
# Imputing row 3701/12741 with 1 missing, elapsed time: 441.792
# Imputing row 3801/12741 with 13 missing, elapsed time: 441.860
# Imputing row 3901/12741 with 0 missing, elapsed time: 441.925
# Imputing row 4001/12741 with 1 missing, elapsed time: 441.982
# Imputing row 4101/12741 with 11 missing, elapsed time: 442.042
# Imputing row 4201/12741 with 2 missing, elapsed time: 442.100
# Imputing row 4301/12741 with 12 missing, elapsed time: 442.161
# Imputing row 4401/12741 with 1 missing, elapsed time: 442.231
# Imputing row 4501/12741 with 1 missing, elapsed time: 442.363
# Imputing row 4601/12741 with 0 missing, elapsed time: 442.440
# Imputing row 4701/12741 with 11 missing, elapsed time: 442.567
# Imputing row 4801/12741 with 11 missing, elapsed time: 442.663
# Imputing row 4901/12741 with 11 missing, elapsed time: 442.743
# Imputing row 5001/12741 with 0 missing, elapsed time: 442.845
# Imputing row 5101/12741 with 12 missing, elapsed time: 442.888
# Imputing row 5201/12741 with 1 missing, elapsed time: 442.927
# Imputing row 5301/12741 with 11 missing, elapsed time: 443.005
# Imputing row 5401/12741 with 0 missing, elapsed time: 443.034
# Imputing row 5501/12741 with 1 missing, elapsed time: 443.067
# Imputing row 5601/12741 with 2 missing, elapsed time: 443.113
# Imputing row 5701/12741 with 1 missing, elapsed time: 443.148
# Imputing row 5801/12741 with 8 missing, elapsed time: 446.190
# Imputing row 5901/12741 with 351 missing, elapsed time: 450.036
# Imputing row 6001/12741 with 339 missing, elapsed time: 454.172
# Imputing row 6101/12741 with 351 missing, elapsed time: 458.062
# Imputing row 6201/12741 with 350 missing, elapsed time: 461.837
# Imputing row 6301/12741 with 344 missing, elapsed time: 465.667
# Imputing row 6401/12741 with 350 missing, elapsed time: 469.167
# Imputing row 6501/12741 with 339 missing, elapsed time: 473.132
# Imputing row 6601/12741 with 350 missing, elapsed time: 476.694
# Imputing row 6701/12741 with 339 missing, elapsed time: 480.100
# Imputing row 6801/12741 with 350 missing, elapsed time: 484.024
# Imputing row 6901/12741 with 4 missing, elapsed time: 487.584
# Imputing row 7001/12741 with 9 missing, elapsed time: 491.574
# Imputing row 7101/12741 with 4 missing, elapsed time: 495.456
# Imputing row 7201/12741 with 351 missing, elapsed time: 498.939
# Imputing row 7301/12741 with 351 missing, elapsed time: 502.641
# Imputing row 7401/12741 with 5 missing, elapsed time: 506.576
# Imputing row 7501/12741 with 339 missing, elapsed time: 510.354
# Imputing row 7601/12741 with 351 missing, elapsed time: 513.909
# Imputing row 7701/12741 with 355 missing, elapsed time: 517.601
# Imputing row 7801/12741 with 350 missing, elapsed time: 520.963
# Imputing row 7901/12741 with 355 missing, elapsed time: 524.848
# Imputing row 8001/12741 with 351 missing, elapsed time: 528.080
# Imputing row 8101/12741 with 355 missing, elapsed time: 531.937
# Imputing row 8201/12741 with 350 missing, elapsed time: 535.501
# Imputing row 8301/12741 with 339 missing, elapsed time: 539.248
# Imputing row 8401/12741 with 351 missing, elapsed time: 542.961
# Imputing row 8501/12741 with 341 missing, elapsed time: 546.544
# Imputing row 8601/12741 with 354 missing, elapsed time: 550.031
# Imputing row 8701/12741 with 4 missing, elapsed time: 553.946
# Imputing row 8801/12741 with 351 missing, elapsed time: 558.094
# Imputing row 8901/12741 with 8 missing, elapsed time: 561.275
# Imputing row 9001/12741 with 354 missing, elapsed time: 563.917
# Imputing row 9101/12741 with 16 missing, elapsed time: 567.725
# Imputing row 9201/12741 with 350 missing, elapsed time: 571.495
# Imputing row 9301/12741 with 0 missing, elapsed time: 574.791
# Imputing row 9401/12741 with 353 missing, elapsed time: 577.890
# Imputing row 9501/12741 with 350 missing, elapsed time: 581.352
# Imputing row 9601/12741 with 351 missing, elapsed time: 585.078
# Imputing row 9701/12741 with 350 missing, elapsed time: 588.290
# Imputing row 9801/12741 with 353 missing, elapsed time: 590.866
# Imputing row 9901/12741 with 0 missing, elapsed time: 593.446
# Imputing row 10001/12741 with 0 missing, elapsed time: 595.965
# Imputing row 10101/12741 with 350 missing, elapsed time: 598.388
# Imputing row 10201/12741 with 6 missing, elapsed time: 601.374
# Imputing row 10301/12741 with 350 missing, elapsed time: 603.803
# Imputing row 10401/12741 with 10 missing, elapsed time: 606.354
# Imputing row 10501/12741 with 18 missing, elapsed time: 608.092
# Imputing row 10601/12741 with 6 missing, elapsed time: 608.793
# Imputing row 10701/12741 with 339 missing, elapsed time: 610.839
# Imputing row 10801/12741 with 10 missing, elapsed time: 613.613
# Imputing row 10901/12741 with 350 missing, elapsed time: 617.043
# Imputing row 11001/12741 with 339 missing, elapsed time: 620.368
# Imputing row 11101/12741 with 5 missing, elapsed time: 623.321
# Imputing row 11201/12741 with 3 missing, elapsed time: 626.512
# Imputing row 11301/12741 with 339 missing, elapsed time: 629.487
# Imputing row 11401/12741 with 351 missing, elapsed time: 632.386
# Imputing row 11501/12741 with 339 missing, elapsed time: 635.916
# Imputing row 11601/12741 with 349 missing, elapsed time: 639.667
# Imputing row 11701/12741 with 350 missing, elapsed time: 644.377
# Imputing row 11801/12741 with 340 missing, elapsed time: 648.051
# Imputing row 11901/12741 with 343 missing, elapsed time: 651.972
# Imputing row 12001/12741 with 343 missing, elapsed time: 655.351
# Imputing row 12101/12741 with 6 missing, elapsed time: 658.202
# Imputing row 12201/12741 with 339 missing, elapsed time: 662.356
# Imputing row 12301/12741 with 339 missing, elapsed time: 665.676
# Imputing row 12401/12741 with 340 missing, elapsed time: 669.861
# Imputing row 12501/12741 with 340 missing, elapsed time: 674.604
# Imputing row 12601/12741 with 340 missing, elapsed time: 679.548
# Imputing row 12701/12741 with 348 missing, elapsed time: 684.454

# %%
# Save imputed data into a dataframe
imp_df = pandas.DataFrame(dat_filled50, columns = good_df.columns[1:-10])
for col in df.columns[:10]:
    imp_df[col] = df[col]
imp_df.to_csv('/Users/jakevogel/Science/TADPOLE/imputed_d1_d2_50p.csv')

# %% [markdown]
# ## Clean the data

# %%
cleaned_df = pandas.DataFrame(imp_df,copy=True)

# %%
# First, fix the Diagnosis variable:
cleaned_df.DX = df.DX
map_df.loc['DX']
# Out:
#                  0
# MCI to NL        6
# NL to MCI        4
# Dementia to MCI  7
# NL to Dementia   9
# NL               1
# MCI to Dementia  5
# Dementia         2
# MCI              3

# %%
newcode = {1:1, 2:3, 3:2, 4:2, 5:3, 6:1, 7:2, 9:3}
cleaned_df.DX = [newcode[x] if pandas.notnull(x) else np.nan for x in cleaned_df.DX ]

# %%
cleaned_df.DX.unique()
# Out:
# array([  1.,   3.,   2.,  nan])

# %%
# Get rid of other DX variable
cleaned_df.drop('DXCHANGE', axis=1, inplace=True)

# %%
# Find variables collinear with ventricles
rs = [x for x in range(cleaned_df.shape[1]
                       ) if cleaned_df[cleaned_df.columns[x]
                                      ].dtype == float and stats.pearsonr(cleaned_df.Ventricles,
                                                           cleaned_df[cleaned_df.columns[x]]
                                                                         )[0] > 0.9]
print('variables collinear with Ventricles and their R value')
list(zip(cleaned_df.columns[rs], 
         [stats.pearsonr(cleaned_df.Ventricles,
                        cleaned_df[cleaned_df.columns[x]]
                        )[0] for x in rs]))
# Out:
# variables collinear with Ventricles and their R value
# [('Ventricles', 1.0),
#  ('Ventricles_bl', 0.94412357398130953),
#  ('ST37SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16', 0.96972591852767887),
#  ('ST96SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16', 0.96470506419028701)]

# %%
# NOT SURE WHETHER OR NOT WE HAVE TO GET RID OF THESE???

# %%
# Find variables that are just ID variables
rs = [x for x in range(cleaned_df.shape[1]
                       ) if cleaned_df[cleaned_df.columns[x]
                                      ].dtype == float and stats.pearsonr(cleaned_df.RID,
                                                           cleaned_df[cleaned_df.columns[x]]
                                                                         )[0] > 0.9]
print('variables collinear with ID variables and their R value')
list(zip(cleaned_df.columns[rs], 
         [stats.pearsonr(cleaned_df.RID,
                        cleaned_df[cleaned_df.columns[x]]
                        )[0] for x in rs]))
# Out:
# variables collinear with Ventricles and their R value
# [('EXAMDATE_bl', 0.94406767788074875),
#  ('FLDSTRENG_bl', 0.91796435956712952),
#  ('FSVERSION_bl', 0.91960104290288747),
#  ('update_stamp_UCSFFSX_11_02_15_UCSFFSX51_08_01_16', 0.93996410482888859)]

# %%
# Now get rid of them
for col in cleaned_df.columns[rs]:
    cleaned_df.drop(col, axis=1, inplace=True)

# %%
# Move index variables and Y variables to a separate dataframe
ref_df = cleaned_df[cleaned_df.columns[-10:]]
ref_df['y_DX'] = cleaned_df['DX']
ref_df['y_ADAS11'] = cleaned_df['ADAS11']
ref_df['y_ADAS13'] = cleaned_df['ADAS13']
ref_df['y_Ventricles_adj_TIV'] = cleaned_df.Ventricles / cleaned_df.ICV
# Out:
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# drop those columns
for col in cleaned_df.columns[-10:].tolist() + ['DX', 'Ventricles', 'ADAS11', 'ADAS13']:
    cleaned_df.drop(col, axis=1, inplace=True)

# %%
# SAVE IT
cleaned_df.to_csv('/Users/jakevogel/Science/TADPOLE/inputed50_cleaned')
ref_df.to_csv('/Users/jakevogel/Science/TADPOLE/inputed50_ref.csv')

# %%
# All at once!
def clean_dataframe(imp_df, old_df, out_name, out_dir = './'):
    
    print('working on',out_name)
    cleaned_df = pandas.DataFrame(imp_df,copy=True)
    newcode = {1:1, 2:3, 3:2, 4:2, 5:3, 6:1, 7:2, 9:3}
    cleaned_df.DX = old_df.DX
    cleaned_df.DX = [newcode[x] if pandas.notnull(x) else np.nan for x in cleaned_df.DX ]
    
    # Get rid of other DX variable
    try:
        cleaned_df.drop('DXCHANGE', axis=1, inplace=True)
    except:
        pass
    
    # Find variables collinear with ventricles
    rs = [x for x in range(cleaned_df.shape[1]
                           ) if cleaned_df[cleaned_df.columns[x]
                                          ].dtype == float and stats.pearsonr(cleaned_df.Ventricles,
                                                               cleaned_df[cleaned_df.columns[x]]
                                                                             )[0] > 0.9]
    print('variables collinear with Ventricles and their R value')
    print(list(zip(cleaned_df.columns[rs], 
             [stats.pearsonr(cleaned_df.Ventricles,
                            cleaned_df[cleaned_df.columns[x]]
                            )[0] for x in rs])))
    
    # Find variables that are just ID variables
    rs = [x for x in range(cleaned_df.shape[1]
                           ) if cleaned_df[cleaned_df.columns[x]
                                          ].dtype == float and stats.pearsonr(cleaned_df.RID,
                                                               cleaned_df[cleaned_df.columns[x]]
                                                                             )[0] > 0.9]
    for col in cleaned_df.columns[rs]:
        print('deleting meaningless column',col)
        cleaned_df.drop(col, axis=1, inplace=True)
    
    # Move index variables and Y variables to a separate dataframe
    ref_df = cleaned_df[cleaned_df.columns[-10:]]
    ref_df['y_DX'] = cleaned_df['DX']
    ref_df['y_ADAS11'] = cleaned_df['ADAS11']
    ref_df['y_ADAS13'] = cleaned_df['ADAS13']
    ref_df['ventr_ICV_ratio'] = cleaned_df['ventr_ICV_ratio']
    
    # drop those columns
    for col in cleaned_df.columns[-10:].tolist() + ['DX', 'Ventricles', 'ADAS11', 'ADAS13','ventr_ICV_ratio']:
        cleaned_df.drop(col, axis=1, inplace=True)
        
    
    cleaned_df.to_csv(os.path.join(out_dir,'%s_cleaned.csv'%out_name))
    ref_df.to_csv(os.path.join(out_dir,'%s_cleaned_ref.csv'%out_name))

# %%
fi.KNN?

# %%
def run_imputation(df, cutoff, out_name, strategy = fi.KNN(), out_dir = './'):
    
    print('preparing data for',out_name)
    # identify percentage of missing values for each column
    missing = []
    n = df.shape[0]
    for col in df.columns[10:]:
        missing.append((len([x for x in df[col] if not pandas.notnull(x)])+0.0000001)/n)
    # get indices of columns to keep, and columns to get rid of
    good_idx = [x+10 for x in range(len(missing)) if missing[x] < cutoff]
    good_df = df[df.columns[good_idx]]
    # scale the data, being sure to avoid NaNs, but also accurately remap to the data
    for i,col in enumerate(good_df.columns):
        print('working on %s of %s'%(i,good_df.shape[-1]))
        if col == 'ventr_ICV_ratio':
            to_scale = good_df[col].dropna(axis=0)
            scaler = FunctionTransformer(np.log).fit(to_scale)
            good_df.loc[to_scale.index,col] = scaler.transform(good_df.loc[to_scale.index,col])
        to_scale = good_df[col].dropna(axis=0)
        scaler = StandardScaler().fit(to_scale)
        good_df.loc[to_scale.index,col] = scaler.transform(good_df.loc[to_scale.index,col])
    
    # IMPUTE THE DATAAAAA ... 
    print('imputing data for',out_name)
    dat_filled = strategy.complete(good_df[good_df.columns])
    # Save imputed data into a dataframe
    imp_df = pandas.DataFrame(dat_filled, columns = good_df.columns)
    for col in df.columns[:10]:
        imp_df[col] = df[col]
    
    # clean up
    print('cleaning up for', out_name)
    clean_dataframe(imp_df, df, out_name)

# %%
approaches = {'KNN_75': [fi.KNN(),0.75], 
              'ISVD_50': [fi.IterativeSVD(), 0.5],
             'ISVD_75': [fi.IterativeSVD(),0.75],
             'KNN_50': [fi.KNN(), 0.50]}

# %%
cutoff = .5
missing = []
n = df.shape[0]
for col in df.columns[10:]:
    missing.append((len([x for x in df[col] if not pandas.notnull(x)])+0.0000001)/n)
# get indices of columns to keep, and columns to get rid of
good_idx = [x+10 for x in range(len(missing)) if missing[x] < cutoff]
good_df = df[df.columns[good_idx]]

# %%
for out_name, inputs in approaches.items():
    run_imputation(df, inputs[-1], out_name, strategy = inputs[0], 
                   out_dir = '/Users/jakevogel/Science/TADPOLE/')
# Out:
# preparing data for KNN_50
# working on 0 of 383
# working on 1 of 383
# working on 2 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 3 of 383
# working on 4 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 5 of 383
# working on 6 of 383
# working on 7 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 8 of 383
# working on 9 of 383
# working on 10 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 11 of 383
# working on 12 of 383
# working on 13 of 383
# working on 14 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 15 of 383
# working on 16 of 383
# working on 17 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 18 of 383
# working on 19 of 383
# working on 20 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 21 of 383
# working on 22 of 383
# working on 23 of 383
# working on 24 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 25 of 383
# working on 26 of 383
# working on 27 of 383
# working on 28 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 29 of 383
# working on 30 of 383
# working on 31 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 32 of 383
# working on 33 of 383
# working on 34 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 35 of 383
# working on 36 of 383
# working on 37 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 38 of 383
# working on 39 of 383
# working on 40 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 41 of 383
# working on 42 of 383
# working on 43 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 44 of 383
# working on 45 of 383
# working on 46 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 47 of 383
# working on 48 of 383
# working on 49 of 383
# working on 50 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 51 of 383
# working on 52 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 53 of 383
# working on 54 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 55 of 383
# working on 56 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 57 of 383
# working on 58 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 59 of 383
# working on 60 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# ...
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 372 of 383
# working on 373 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 374 of 383
# working on 375 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 376 of 383
# working on 377 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 378 of 383
# working on 379 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# working on 380 of 383
# working on 381 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# working on 382 of 383
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# imputing data for ISVD_50
# [IterativeSVD] Iter 1: observed MAE=0.692640
# [IterativeSVD] Iter 2: observed MAE=0.634813
# [IterativeSVD] Iter 3: observed MAE=0.583820
# [IterativeSVD] Iter 4: observed MAE=0.537309
# [IterativeSVD] Iter 5: observed MAE=0.521040
# [IterativeSVD] Iter 6: observed MAE=0.519750
# [IterativeSVD] Iter 7: observed MAE=0.518864
# [IterativeSVD] Iter 8: observed MAE=0.518216
# [IterativeSVD] Iter 9: observed MAE=0.517728
# [IterativeSVD] Iter 10: observed MAE=0.517347
# [IterativeSVD] Iter 11: observed MAE=0.517041
# [IterativeSVD] Iter 12: observed MAE=0.516785
# [IterativeSVD] Iter 13: observed MAE=0.516565
# [IterativeSVD] Iter 14: observed MAE=0.516373
# [IterativeSVD] Iter 15: observed MAE=0.516203
# [IterativeSVD] Iter 16: observed MAE=0.516051
# [IterativeSVD] Iter 17: observed MAE=0.515915
# [IterativeSVD] Iter 18: observed MAE=0.515791
# [IterativeSVD] Iter 19: observed MAE=0.515679
# [IterativeSVD] Iter 20: observed MAE=0.515576
# [IterativeSVD] Iter 21: observed MAE=0.515481
# [IterativeSVD] Iter 22: observed MAE=0.515394
# [IterativeSVD] Iter 23: observed MAE=0.515312
# [IterativeSVD] Iter 24: observed MAE=0.515236
# [IterativeSVD] Iter 25: observed MAE=0.515163
# [IterativeSVD] Iter 26: observed MAE=0.515095
# [IterativeSVD] Iter 27: observed MAE=0.515031
# [IterativeSVD] Iter 28: observed MAE=0.514969
# [IterativeSVD] Iter 29: observed MAE=0.514911
# [IterativeSVD] Iter 30: observed MAE=0.514855
# [IterativeSVD] Iter 31: observed MAE=0.514801
# [IterativeSVD] Iter 32: observed MAE=0.514750
# [IterativeSVD] Iter 33: observed MAE=0.514701
# [IterativeSVD] Iter 34: observed MAE=0.514654
# [IterativeSVD] Iter 35: observed MAE=0.514609
# [IterativeSVD] Iter 36: observed MAE=0.514566
# [IterativeSVD] Iter 37: observed MAE=0.514524
# [IterativeSVD] Iter 38: observed MAE=0.514484
# [IterativeSVD] Iter 39: observed MAE=0.514445
# [IterativeSVD] Iter 40: observed MAE=0.514408
# [IterativeSVD] Iter 41: observed MAE=0.514372
# [IterativeSVD] Iter 42: observed MAE=0.514337
# [IterativeSVD] Iter 43: observed MAE=0.514304
# [IterativeSVD] Iter 44: observed MAE=0.514271
# [IterativeSVD] Iter 45: observed MAE=0.514239
# [IterativeSVD] Iter 46: observed MAE=0.514209
# [IterativeSVD] Iter 47: observed MAE=0.514179
# [IterativeSVD] Iter 48: observed MAE=0.514150
# [IterativeSVD] Iter 49: observed MAE=0.514123
# [IterativeSVD] Iter 50: observed MAE=0.514096
# [IterativeSVD] Iter 51: observed MAE=0.514071
# [IterativeSVD] Iter 52: observed MAE=0.514046
# [IterativeSVD] Iter 53: observed MAE=0.514022
# [IterativeSVD] Iter 54: observed MAE=0.513998
# [IterativeSVD] Iter 55: observed MAE=0.513975
# [IterativeSVD] Iter 56: observed MAE=0.513953
# [IterativeSVD] Iter 57: observed MAE=0.513931
# [IterativeSVD] Iter 58: observed MAE=0.513910
# [IterativeSVD] Iter 59: observed MAE=0.513890
# [IterativeSVD] Iter 60: observed MAE=0.513870
# [IterativeSVD] Iter 61: observed MAE=0.513850
# [IterativeSVD] Iter 62: observed MAE=0.513832
# [IterativeSVD] Iter 63: observed MAE=0.513813
# [IterativeSVD] Iter 64: observed MAE=0.513795
# [IterativeSVD] Iter 65: observed MAE=0.513777
# [IterativeSVD] Iter 66: observed MAE=0.513760
# [IterativeSVD] Iter 67: observed MAE=0.513743
# [IterativeSVD] Iter 68: observed MAE=0.513727
# [IterativeSVD] Iter 69: observed MAE=0.513710
# [IterativeSVD] Iter 70: observed MAE=0.513694
# [IterativeSVD] Iter 71: observed MAE=0.513679
# [IterativeSVD] Iter 72: observed MAE=0.513664
# [IterativeSVD] Iter 73: observed MAE=0.513649
# [IterativeSVD] Iter 74: observed MAE=0.513634
# [IterativeSVD] Iter 75: observed MAE=0.513620
# [IterativeSVD] Iter 76: observed MAE=0.513606
# [IterativeSVD] Iter 77: observed MAE=0.513592
# [IterativeSVD] Iter 78: observed MAE=0.513578
# [IterativeSVD] Iter 79: observed MAE=0.513565
# [IterativeSVD] Iter 80: observed MAE=0.513552
# [IterativeSVD] Iter 81: observed MAE=0.513539
# [IterativeSVD] Iter 82: observed MAE=0.513526
# [IterativeSVD] Iter 83: observed MAE=0.513514
# [IterativeSVD] Iter 84: observed MAE=0.513502
# [IterativeSVD] Iter 85: observed MAE=0.513490
# [IterativeSVD] Iter 86: observed MAE=0.513478
# [IterativeSVD] Iter 87: observed MAE=0.513466
# [IterativeSVD] Iter 88: observed MAE=0.513454
# [IterativeSVD] Iter 89: observed MAE=0.513443
# [IterativeSVD] Iter 90: observed MAE=0.513432
# [IterativeSVD] Iter 91: observed MAE=0.513421
# [IterativeSVD] Iter 92: observed MAE=0.513410
# [IterativeSVD] Iter 93: observed MAE=0.513399
# [IterativeSVD] Iter 94: observed MAE=0.513389
# [IterativeSVD] Iter 95: observed MAE=0.513379
# [IterativeSVD] Iter 96: observed MAE=0.513368
# [IterativeSVD] Iter 97: observed MAE=0.513358
# [IterativeSVD] Iter 98: observed MAE=0.513348
# [IterativeSVD] Iter 99: observed MAE=0.513339
# [IterativeSVD] Iter 100: observed MAE=0.513329
# [IterativeSVD] Iter 101: observed MAE=0.513319
# [IterativeSVD] Iter 102: observed MAE=0.513310
# [IterativeSVD] Iter 103: observed MAE=0.513301
# [IterativeSVD] Iter 104: observed MAE=0.513291
# [IterativeSVD] Iter 105: observed MAE=0.513282
# [IterativeSVD] Iter 106: observed MAE=0.513274
# [IterativeSVD] Iter 107: observed MAE=0.513265
# [IterativeSVD] Iter 108: observed MAE=0.513256
# [IterativeSVD] Iter 109: observed MAE=0.513248
# [IterativeSVD] Iter 110: observed MAE=0.513239
# [IterativeSVD] Iter 111: observed MAE=0.513231
# [IterativeSVD] Iter 112: observed MAE=0.513223
# [IterativeSVD] Iter 113: observed MAE=0.513215
# [IterativeSVD] Iter 114: observed MAE=0.513207
# [IterativeSVD] Iter 115: observed MAE=0.513199
# [IterativeSVD] Iter 116: observed MAE=0.513191
# [IterativeSVD] Iter 117: observed MAE=0.513184
# [IterativeSVD] Iter 118: observed MAE=0.513176
# [IterativeSVD] Iter 119: observed MAE=0.513169
# [IterativeSVD] Iter 120: observed MAE=0.513161
# [IterativeSVD] Iter 121: observed MAE=0.513154
# [IterativeSVD] Iter 122: observed MAE=0.513147
# [IterativeSVD] Iter 123: observed MAE=0.513140
# [IterativeSVD] Iter 124: observed MAE=0.513133
# [IterativeSVD] Iter 125: observed MAE=0.513126
# [IterativeSVD] Iter 126: observed MAE=0.513120
# [IterativeSVD] Iter 127: observed MAE=0.513113
# [IterativeSVD] Iter 128: observed MAE=0.513107
# [IterativeSVD] Iter 129: observed MAE=0.513100
# [IterativeSVD] Iter 130: observed MAE=0.513094
# [IterativeSVD] Iter 131: observed MAE=0.513088
# [IterativeSVD] Iter 132: observed MAE=0.513081
# [IterativeSVD] Iter 133: observed MAE=0.513075
# [IterativeSVD] Iter 134: observed MAE=0.513069
# [IterativeSVD] Iter 135: observed MAE=0.513063
# [IterativeSVD] Iter 136: observed MAE=0.513058
# [IterativeSVD] Iter 137: observed MAE=0.513052
# [IterativeSVD] Iter 138: observed MAE=0.513046
# [IterativeSVD] Iter 139: observed MAE=0.513041
# [IterativeSVD] Iter 140: observed MAE=0.513035
# [IterativeSVD] Iter 141: observed MAE=0.513030
# cleaning up for ISVD_50
# working on ISVD_50
# variables collinear with Ventricles and their R value
# [('Ventricles', 1.0), ('Ventricles_bl', 0.92253556709614759), ('ST37SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16', 0.97165482564288708), ('ST96SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16', 0.96739007257484011), ('ventr_ICV_ratio', 0.93059598809520139)]
# deleting meaningless column FLDSTRENG
# deleting meaningless column EXAMDATE_bl
# deleting meaningless column FLDSTRENG_bl
# deleting meaningless column FSVERSION_bl
# deleting meaningless column update_stamp_UCSFFSX_11_02_15_UCSFFSX51_08_01_16

# %%
fi.KNN?

# %%
78/90
# Out:
# 0.8666666666666667

# %%
df.ventr_ICV_ratio
